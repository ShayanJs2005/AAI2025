# %% [markdown]
# <a href="https://colab.research.google.com/github/ShayanJs2005/AAI2025/blob/2026fall/ML/customer_segmentation3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Exercise 3: Self-Reflection Prompt for Improving Output

# -----------------------------------
# ORIGINAL SUMMARY
# -----------------------------------

original_summary = """
Artificial intelligence helps businesses work faster and make better decisions.
Companies can use AI in many departments, including customer service, marketing,
and operations. AI is becoming more common because it can automate tasks and
help companies analyze information.
"""

print("ORIGINAL SUMMARY:")
print(original_summary)


# -----------------------------------
# SELF-REFLECTION / CRITIQUE
# -----------------------------------

print("\nSELF-REFLECTION / CRITIQUE:")

critique = [
    "Accuracy: The summary is generally accurate, but it is very broad.",
    "Clarity: The wording is understandable, but phrases such as 'work faster' are vague.",
    "Audience: The language is appropriate for a college business student.",
    "Length: The summary is shorter than the required 80-120 words.",
    "Focus: It mentions business areas but does not provide enough specific examples of AI creating value.",
    "Formatting: The summary should remain one clear paragraph."
]

for item in critique:
    print("-", item)


# -----------------------------------
# IMPROVED SUMMARY
# -----------------------------------

improved_summary = """
Artificial intelligence helps businesses improve efficiency, analyze data,
and support better decision-making. For example, companies can use AI-powered
chatbots in customer service to answer common questions quickly and reduce
employee workload. Marketing teams can use AI to analyze customer behavior and
create more personalized campaigns. Businesses can also use AI in operations
to forecast demand, manage inventory, and identify patterns in large datasets.
These applications can save time and improve productivity, but companies
should still use human oversight to review important decisions and ensure
that AI systems are used responsibly.
"""

print("\nIMPROVED SUMMARY:")
print(improved_summary)
# Out:
# ORIGINAL SUMMARY:
#
# Artificial intelligence helps businesses work faster and make better decisions.
# Companies can use AI in many departments, including customer service, marketing,
# and operations. AI is becoming more common because it can automate tasks and
# help companies analyze information.
#
#
# SELF-REFLECTION / CRITIQUE:
# - Accuracy: The summary is generally accurate, but it is very broad.
# - Clarity: The wording is understandable, but phrases such as 'work faster' are vague.
# - Audience: The language is appropriate for a college business student.
# - Length: The summary is shorter than the required 80-120 words.
# - Focus: It mentions business areas but does not provide enough specific examples of AI creating value.
# - Formatting: The summary should remain one clear paragraph.
#
# IMPROVED SUMMARY:
#
# Artificial intelligence helps businesses improve efficiency, analyze data,
# and support better decision-making. For example, companies can use AI-powered
# ...

# %% [markdown]
# Exercise 3: Self-Reflection Prompt for Improving Output
#
# Goal:
# Ask the AI to critique and improve its own summary using clear requirements.
#
# Tools Used:
# - Chat and Claude
# - Google Colab
# - Python and Git hub
#
# Original Prompt:
# Write a short summary explaining how artificial intelligence is used in business.
#
# Original Summary:
# Artificial intelligence helps businesses work faster and make better decisions. Companies can use AI in many departments, including customer service, marketing, and operations. AI is becoming more common because it can automate tasks and help companies analyze information.
#
# Self-Reflection Prompt:
# Review the original summary and evaluate it using these criteria:
#
# 1. Accuracy:
# Check whether the claims are reasonable and not misleading.
#
# 2. Clarity:
# Make sure the summary is easy to understand and avoids vague wording.
#
# 3. Audience:
# Make sure the summary is appropriate for a college business student with basic knowledge of AI.
#
# 4. Length:
# The revised summary should be between 80 and 120 words.
#
# 5. Focus:
# Explain how AI creates value for businesses and include at least two specific examples.
#
# 6. Formatting:
# The final summary should be written as one clear paragraph.
#
# 7. Revision:
# After identifying weaknesses, rewrite the summary so it meets all of the requirements.
#
# Testing and Improvement:
#
# Before:
# The original summary was understandable, but it was too general and did not include enough specific examples.
#
# Critique:
# The self-reflection process identified weaknesses in accuracy, clarity, audience, length, focus, and formatting.
#
# After:
# The revised summary added specific examples such as AI chatbots, customer behavior analysis, demand forecasting, and inventory management. It also explained more clearly how AI can improve efficiency and support business decision-making.
#
# Why This Follows Self-Reflection:
# The AI first reviews its own original output against specific criteria, identifies weaknesses, and then creates an improved version based on that critique.
